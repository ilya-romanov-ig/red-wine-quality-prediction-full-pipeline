# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from xgboost.sklearn import XGBClassifier
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.model_selection import GridSearchCV

# %%
import sys

sys.path.append('..')
from src.data.preprocessing import DataPreprocessor

df = pd.read_csv('../data/raw/data.csv')
X = df.drop('quality', axis=1)
y = df['quality']

dp = DataPreprocessor()
X_train, X_test, y_train, y_test = dp.fit_transform(X, y)

# %%
gc_results = {}

# %%
params = {
    'n_estimators': [100, 150, 200],
    'max_depth': [3, 4, 5, 6, 8],
    'max_features': ['sqrt', 'log2', None],
    'max_leaf_nodes': [None, 5, 10],
    'min_samples_leaf': [1, 2, 3],
    'min_samples_split': [2, 4, 6]
}

gc = GridSearchCV(
    RandomForestClassifier(random_state=42),
    params,
    scoring='accuracy',
    n_jobs=-1
)

gc.fit(X_train, y_train)

gc_results['RandomForestClassifier'] = {
    'model': gc.best_estimator_,
    'best_params': gc.best_params_,
    'accuracy_score': gc.best_score_
}

# %%
params = {
    'max_depth': [3, 4, 5, 6, 8],
    'learning_rate': [0.01, 0.05, 0.1, 0.15],
    'n_estimators': [100, 150, 200],
    'min_child_weight': [1, 3, 5, 7],
    'gamma': [0.0, 0.1, 0.2, 0.4],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
}

gc = GridSearchCV(
    XGBClassifier(random_state=42),
    params,
    scoring='accuracy',
    n_jobs=-1
)

gc.fit(X_train, y_train)

gc_results['XGBClassifier'] = {
    'model': gc.best_estimator_,
    'best_params': gc.best_params_,
    'accuracy_score': gc.best_score_
}

# %%
gc_results
# Out:
# {'RandomForestClassifier': {'model': RandomForestClassifier(max_depth=8, min_samples_split=4, random_state=42),
#   'best_params': {'max_depth': 8,
#    'max_features': 'sqrt',
#    'max_leaf_nodes': None,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4,
#    'n_estimators': 100},
#   'accuracy_score': np.float64(0.8866421568627452)},
#  'XGBClassifier': {'model': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 feature_weights=None, gamma=0.1, grow_policy=None,
#                 importance_type=None, interaction_constraints=None,
#                 learning_rate=0.15, max_bin=None, max_cat_threshold=None,
#                 max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#                 max_leaves=None, min_child_weight=1, missing=nan,
#                 monotone_constraints=None, multi_strategy=None, n_estimators=150,
#                 n_jobs=None, num_parallel_tree=None, ...),
#   'best_params': {'colsample_bytree': 1.0,
#    'gamma': 0.1,
#    'learning_rate': 0.15,
#    'max_depth': 5,
#    'min_child_weight': 1,
#    'n_estimators': 150,
#    'subsample': 0.6},
#   'accuracy_score': np.float64(0.8991544117647059)}}

# %% [markdown]
# ## Optuna

# %%
optuna_results = {}

# %% [markdown]
# ### Random Forest

# %%
import optuna
from sklearn.model_selection import cross_val_score

def RF(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 10, 200),
        'max_depth': trial.suggest_int('max_depth', 2, 32),
        'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2']),
        'max_leaf_nodes': trial.suggest_int('max_leaf_nodes', 5, 20),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 20),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
    }

    clf = RandomForestClassifier(**params, random_state=42)

    score = cross_val_score(clf, X_train, y_train, n_jobs=-1, cv=5, scoring='accuracy').mean()

    return score

study = optuna.create_study(direction='maximize')
study.optimize(RF, n_trials=50)

optuna_results['RandomForestClassifier'] = study
# Out:
# [I 2026-01-02 01:12:41,781] A new study created in memory with name: no-name-1721e074-7818-4ca2-bda4-fa05a2e1f5b5
# [I 2026-01-02 01:12:41,883] Trial 0 finished with value: 0.8717830882352942 and parameters: {'n_estimators': 41, 'max_depth': 23, 'max_features': 'sqrt', 'max_leaf_nodes': 7, 'min_samples_split': 14, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.8717830882352942.
# [I 2026-01-02 01:12:42,138] Trial 1 finished with value: 0.8702236519607844 and parameters: {'n_estimators': 109, 'max_depth': 32, 'max_features': 'log2', 'max_leaf_nodes': 11, 'min_samples_split': 13, 'min_samples_leaf': 6}. Best is trial 0 with value: 0.8717830882352942.
# [I 2026-01-02 01:12:42,413] Trial 2 finished with value: 0.8710049019607844 and parameters: {'n_estimators': 124, 'max_depth': 19, 'max_features': 'log2', 'max_leaf_nodes': 14, 'min
ean()

    return score

study = optuna.create_study(direction='maximize')
study.optimize(XGB, n_trials=50)

optuna_results['XGBClassifier'] = study
# Out:
# [I 2026-01-02 01:10:54,192] A new study created in memory with name: no-name-adc6fcd9-76b2-4028-9f98-c75011c756fb
# [I 2026-01-02 01:10:54,269] Trial 0 finished with value: 0.8749080882352942 and parameters: {'max_depth': 6, 'learning_rate': 0.03621691005971648, 'n_estimators': 119, 'min_child_weight': 12, 'gamma': 5.745567428477994e-06, 'subsample': 0.4935941083684259, 'colsample_bytree': 0.6930215870933208}. Best is trial 0 with value: 0.8749080882352942.
# [I 2026-01-02 01:10:54,318] Trial 1 finished with value: 0.8639583333333334 and parameters: {'max_depth': 8, 'learning_rate': 0.026135281985661674, 'n_estimators': 25, 'min_child_weight': 7, 'gamma': 8.892532470293681e-05, 'subsample': 0.7356983606119052, 'colsample_bytree': 0.7339749257901653}. Best is trial 0 with value: 0.8749080882352942.
# [I 2026-01-02 01:10:54,357] Trial 2 finished with value: 0.8639583333333334 and parameters: {'max_depth': 16, 'learning_rate': 0.029219639998598293, 'n_estimators': 20, 'min_child_weight': 5, 'gamma': 0.00563693099358333, 'subsample': 0.5076474502156505, 'colsample_bytree': 0.736328636069912}. Best is trial 0 with value: 0.8749080882352942.
# [I 2026-01-02 01:10:54,406] Trial 3 finished with value: 0.8639583333333334 and parameters: {'max_depth': 24, 'learning_rate': 0.009866970988763773, 'n_estimators': 73, 'min_child_weight': 11, 'gamma': 0.40263439982289584, 'subsample': 0.10193948804627721, 'colsample_bytree': 0.8641391146018678}. Best is trial 0 with value: 0.8749080882352942.
# [I 2026-01-02 01:10:54,477] Trial 4 finished with value: 0.8639583333333334 and parameters: {'max_depth': 2, 'learning_rate': 0.00235851105371864, 'n_estimators': 138, 'min_child_weight': 3, 'gamma': 0.0016066817335598554, 'subsample': 0.8626967378538681, 'colsample_bytree': 0.7396125104235761}. Best is trial 0 with value: 0.8749080882352942.
# [I 2026-01-02 01:10:54,558] Trial 5 finished with value: 0.8639583333333334 and parameters: {'max_depth': 32, 'learning_rate': 0.005349347082405419, 'n_estimators': 95, 'min_child_weight': 8, 'gamma': 0.00011307956405084877, 'subsample': 0.9893063863352898, 'colsample_bytree': 0.7773762873385399}. Best is trial 0 with value: 0.8749080882352942.
# [I 2026-01-02 01:10:54,607] Trial 6 finished with value: 0.8639583333333334 and parameters: {'max_depth': 14, 'learning_rate': 0.002910863763102826, 'n_estimators': 49, 'min_child_weight': 8, 'gamma': 4.32678215324024e-05, 'subsample': 0.6508389007167883, 'colsample_bytree': 0.9932499913000188}. Best is trial 0 with value: 0.8749080882352942.
# [I 2026-01-02 01:10:56,106] Trial 7 finished with value: 0.8639583333333334 and parameters: {'max_depth': 17, 'learning_rate': 0.003152505634301419, 'n_estimators': 178, 'min_child_weight': 10, 'gamma': 1.9013994932925108e-06, 'subsample': 0.3209107269425876, 'colsample_bytree': 0.7787312218491752}. Best is trial 0 with value: 0.8749080882352942.
# [I 2026-01-02 01:10:57,598] Trial 8 finished with value: 0.8686611519607844 and parameters: {'max_depth': 24, 'learning_rate': 0.059654565694290354, 'n_estimators': 197, 'min_child_weight': 4, 'gamma': 0.00015058800200053724, 'subsample': 0.12242573652913762, 'colsample_bytree': 0.7350495738828886}. Best is trial 0 with value: 0.8749080882352942.
# [I 2026-01-02 01:10:57,667] Trial 9 finished with value: 0.869436274509804 and parameters: {'max_depth': 31, 'learning_rate': 0.0635325594141474, 'n_estimators': 145, 'min_child_weight': 12, 'gamma': 8.313713997616917e-08, 'subsample': 0.8037413998422475, 'colsample_bytree': 0.6859361940915125}. Best is trial 0 with value: 0.8749080882352942.
# [I 2026-01-02 01:10:57,727] Trial 10 finished with value: 0.8639583333333334 and parameters: {'max_depth': 2, 'learning_rate': 0.01827212807740697, 'n_estimators': 127, 'min_child_weight': 15, 'gamma': 1.585879254282934e-08, 'subsample': 0.4391548272654426, 'colsample_bytree': 0.5060406519901767}. Best is trial 0 with value: 0.8749080882352942.
# [I 2026-01-02 01:10:57,808] Trial 11 finished with value: 0.872561274509804 and parameters: {'max_depth': 32, 'learning_rate': 0.08687889493225096, 'n_estimators': 151, 'min_child_weight': 14, 'gamma': 7.294448119581037e-08, 'subsample': 0.6947031377817403, 'colsample_bytree': 0.5490925294835397}. Best is trial 0 with value: 0.8749080882352942.
# [I 2026-01-02 01:10:57,890] Trial 12 finished with value: 0.8686611519607844 and parameters: {'max_depth': 10, 'learning_rate': 0.09403881839490451, 'n_estimators': 161, 'min_child_weight': 15, 'gamma': 1.0687312066944895e-06, 'subsample': 0.5892876522320266, 'colsample_bytree': 0.5540639548016777}. Best is trial 0 with value: 0.8749080882352942.
# [I 2026-01-02 01:10:57,959] Trial 13 finished with value: 0.8639583333333334 and parameters: {'max_depth': 25, 'learning_rate': 0.0010439577866269926, 'n_estimators': 110, 'min_child_weight': 13, 'gamma': 6.983143661784395e-07, 'subsample': 0.4044977859516821, 'colsample_bytree': 0.6046787100035258}. Best is trial 0 with value: 0.8749080882352942.
# [I 2026-01-02 01:10:58,020] Trial 14 finished with value: 0.8741299019607844 and parameters: {'max_depth': 7, 'learning_rate': 0.041588101071906684, 'n_estimators': 91, 'min_child_weight': 13, 'gamma': 6.142413512578849e-06, 'subsample': 0.6449440293270421, 'colsample_bytree': 0.6226283157573238}. Best is trial 0 with value: 0.8749080882352942.
# [I 2026-01-02 01:10:58,080] Trial 15 finished with value: 0.8709895833333334 and parameters: {'max_depth': 7, 'learning_rate': 0.03819349063702816, 'n_estimators': 83, 'min_child_weight': 10, 'gamma': 4.8830643607918684e-06, 'subsample': 0.28816249226794616, 'colsample_bytree': 0.6272284754888369}. Best is trial 0 with value: 0.8749080882352942.
# [I 2026-01-02 01:10:58,140] Trial 16 finished with value: 0.8639583333333334 and parameters: {'max_depth': 12, 'learning_rate': 0.012104318388575907, 'n_estimators': 60, 'min_child_weight': 12, 'gamma': 9.979262983621856e-06, 'subsample': 0.5767575921502494, 'colsample_bytree': 0.6503157972941463}. Best is trial 0 with value: 0.8749080882352942.
# [I 2026-01-02 01:10:58,210] Trial 17 finished with value: 0.8788235294117648 and parameters: {'max_depth': 5, 'learning_rate': 0.041119304964595635, 'n_estimators': 109, 'min_child_weight': 10, 'gamma': 0.00784484746318253, 'subsample': 0.48118410049658517, 'colsample_bytree': 0.8516963064195123}. Best is trial 17 with value: 0.8788235294117648.
# [I 2026-01-02 01:10:58,311] Trial 18 finished with value: 0.878045343137255 and parameters: {'max_depth': 5, 'learning_rate': 0.017098877658440106, 'n_estimators': 117, 'min_child_weight': 1, 'gamma': 0.06496213551179775, 'subsample': 0.2491743957311529, 'colsample_bytree': 0.8916520896263693}. Best is trial 17 with value: 0.8788235294117648.
# [I 2026-01-02 01:10:58,403] Trial 19 finished with value: 0.867873774509804 and parameters: {'max_depth': 20, 'learning_rate': 0.01142877798335004, 'n_estimators': 107, 'min_child_weight': 1, 'gamma': 0.1677626196906734, 'subsample': 0.2238462222727598, 'colsample_bytree': 0.8917175352399537}. Best is trial 17 with value: 0.8788235294117648.
# [I 2026-01-02 01:10:58,495] Trial 20 finished with value: 0.8772610294117648 and parameters: {'max_depth': 3, 'learning_rate': 0.01875674503541168, 'n_estimators': 171, 'min_child_weight': 1, 'gamma': 0.049848181739719714, 'subsample': 0.22444481066638636, 'colsample_bytree': 0.8521466746573727}. Best is trial 17 with value: 0.8788235294117648.
# [I 2026-01-02 01:10:58,601] Trial 21 finished with value: 0.8796017156862745 and parameters: {'max_depth': 4, 'learning_rate': 0.01875414754646767, 'n_estimators': 171, 'min_child_weight': 1, 'gamma': 0.053981622971604054, 'subsample': 0.2177055166201885, 'colsample_bytree': 0.872484424415323}. Best is trial 21 with value: 0.8796017156862745.
# [I 2026-01-02 01:10:58,718] Trial 22 finished with value: 0.8702205882352942 and parameters: {'max_depth': 4, 'learning_rate': 0.006922773704834389, 'n_estimators': 199, 'min_child_weight': 3, 'gamma': 0.020913035674756362, 'subsample': 0.3607647118912781, 'colsample_bytree': 0.932420727390778}. Best is trial 21 with value: 0.8796017156862745.
# [I 2026-01-02 01:10:58,811] Trial 23 finished with value: 0.8756985294117647 and parameters: {'max_depth': 11, 'learning_rate': 0.01939807414837654, 'n_estimators': 129, 'min_child_weight': 2, 'gamma': 0.0015427610810141792, 'subsample': 0.20731709990327846, 'colsample_bytree': 0.8306076115368168}. Best is trial 21 with value: 0.8796017156862745.
# [I 2026-01-02 01:10:58,904] Trial 24 finished with value: 0.8756924019607844 and parameters: {'max_depth': 5, 'learning_rate': 0.014363600742184443, 'n_estimators': 181, 'min_child_weight': 6, 'gamma': 0.6384391769476326, 'subsample': 0.28517825958106385, 'colsample_bytree': 0.9442899707760907}. Best is trial 21 with value: 0.8796017156862745.
# [I 2026-01-02 01:10:58,955] Trial 25 finished with value: 0.8639583333333334 and parameters: {'max_depth': 9, 'learning_rate': 0.05276125737645526, 'n_estimators': 47, 'min_child_weight': 9, 'gamma': 0.051705970251171476, 'subsample': 0.15054199287100517, 'colsample_bytree': 0.8155697775332664}. Best is trial 21 with value: 0.8796017156862745.
# [I 2026-01-02 01:10:59,037] Trial 26 finished with value: 0.8639583333333334 and parameters: {'max_depth': 13, 'learning_rate': 0.007622106622168651, 'n_estimators': 117, 'min_child_weight': 4, 'gamma': 0.006925448976433827, 'subsample': 0.4238005503020348, 'colsample_bytree': 0.9046101238755885}. Best is trial 21 with value: 0.8796017156862745.
# [I 2026-01-02 01:10:59,131] Trial 27 finished with value: 0.8694393382352942 and parameters: {'max_depth': 4, 'learning_rate': 0.02774090060187915, 'n_estimators': 152, 'min_child_weight': 2, 'gamma': 0.0004896680721390522, 'subsample': 0.18153590484240842, 'colsample_bytree': 0.9803456425738171}. Best is trial 21 with value: 0.8796017156862745.
# [I 2026-01-02 01:10:59,216] Trial 28 finished with value: 0.8717922794117647 and parameters: {'max_depth': 9, 'learning_rate': 0.023101713800168438, 'n_estimators': 136, 'min_child_weight': 5, 'gamma': 0.14488357575277552, 'subsample': 0.3575972372842151, 'colsample_bytree': 0.8047543438023195}. Best is trial 21 with value: 0.8796017156862745.
# [I 2026-01-02 01:10:59,287] Trial 29 finished with value: 0.8749172794117648 and parameters: {'max_depth': 5, 'learning_rate': 0.04319188140637359, 'n_estimators': 100, 'min_child_weight': 7, 'gamma': 0.010730817191648513, 'subsample': 0.5160147388617315, 'colsample_bytree': 0.8993246639234463}. Best is trial 21 with value: 0.8796017156862745.
# [I 2026-01-02 01:10:59,390] Trial 30 finished with value: 0.8733455882352942 and parameters: {'max_depth': 7, 'learning_rate': 0.015106698703800136, 'n_estimators': 121, 'min_child_weight': 1, 'gamma': 0.001069898542993444, 'subsample': 0.2662086621062715, 'colsample_bytree': 0.9423020232830888}. Best is trial 21 with value: 0.8796017156862745.
# [I 2026-01-02 01:10:59,472] Trial 31 finished with value: 0.8780361519607844 and parameters: {'max_depth': 2, 'learning_rate': 0.018451899376817023, 'n_estimators': 166, 'min_child_weight': 1, 'gamma': 0.04533196200519933, 'subsample': 0.2413085158908679, 'colsample_bytree': 0.8593975224044296}. Best is trial 21 with value: 0.8796017156862745.
# [I 2026-01-02 01:10:59,575] Trial 32 finished with value: 0.8772579656862746 and parameters: {'max_depth': 6, 'learning_rate': 0.03279816095556202, 'n_estimators': 167, 'min_child_weight': 2, 'gamma': 0.04400604876513517, 'subsample': 0.4592677984498833, 'colsample_bytree': 0.8681592794265557}. Best is trial 21 with value: 0.8796017156862745.
# [I 2026-01-02 01:10:59,669] Trial 33 finished with value: 0.8772549019607844 and parameters: {'max_depth': 2, 'learning_rate': 0.02307186030867413, 'n_estimators': 188, 'min_child_weight': 3, 'gamma': 0.9876293884689061, 'subsample': 0.3645108761064545, 'colsample_bytree': 0.847744373933104}. Best is trial 21 with value: 0.8796017156862745.
# [I 2026-01-02 01:10:59,777] Trial 34 finished with value: 0.8639583333333334 and parameters: {'max_depth': 5, 'learning_rate': 0.008195026784041756, 'n_estimators': 161, 'min_child_weight': 1, 'gamma': 0.21587959414041827, 'subsample': 0.16812221411423947, 'colsample_bytree': 0.7760351493586695}. Best is trial 21 with value: 0.8796017156862745.
# [I 2026-01-02 01:10:59,839] Trial 35 finished with value: 0.8725674019607844 and parameters: {'max_depth': 8, 'learning_rate': 0.030584436521956526, 'n_estimators': 67, 'min_child_weight': 4, 'gamma': 0.0053436673667976095, 'subsample': 0.260580242745375, 'colsample_bytree': 0.9197008898106099}. Best is trial 21 with value: 0.8796017156862745.
# [I 2026-01-02 01:10:59,926] Trial 36 finished with value: 0.8639583333333334 and parameters: {'max_depth': 3, 'learning_rate': 0.009754689590152599, 'n_estimators': 141, 'min_child_weight': 2, 'gamma': 0.01522989704671728, 'subsample': 0.10855942201967689, 'colsample_bytree': 0.877471731481465}. Best is trial 21 with value: 0.8796017156862745.
# [I 2026-01-02 01:10:59,985] Trial 37 finished with value: 0.8639583333333334 and parameters: {'max_depth': 15, 'learning_rate': 0.0051340117966116785, 'n_estimators': 33, 'min_child_weight': 5, 'gamma': 0.003394798514288956, 'subsample': 0.32147260195171057, 'colsample_bytree': 0.9586280738743379}. Best is trial 21 with value: 0.8796017156862745.
# [I 2026-01-02 01:11:00,047] Trial 38 finished with value: 0.8639583333333334 and parameters: {'max_depth': 20, 'learning_rate': 0.01525633266843791, 'n_estimators': 85, 'min_child_weight': 10, 'gamma': 0.11683123517168786, 'subsample': 0.4998224985472399, 'colsample_bytree': 0.8292859659934132}. Best is trial 21 with value: 0.8796017156862745.
# [I 2026-01-02 01:11:00,132] Trial 39 finished with value: 0.8803860294117648 and parameters: {'max_depth': 2, 'learning_rate': 0.024981717225619048, 'n_estimators': 187, 'min_child_weight': 8, 'gamma': 0.016255999187808713, 'subsample': 0.9489402109158236, 'colsample_bytree': 0.7686312613395537}. Best is trial 39 with value: 0.8803860294117648.
# [I 2026-01-02 01:11:00,244] Trial 40 finished with value: 0.8686642156862746 and parameters: {'max_depth': 10, 'learning_rate': 0.04982370748553198, 'n_estimators': 187, 'min_child_weight': 9, 'gamma': 0.00027958464472623804, 'subsample': 0.8569231730711422, 'colsample_bytree': 0.7026306511049207}. Best is trial 39 with value: 0.8803860294117648.
# [I 2026-01-02 01:11:00,325] Trial 41 finished with value: 0.8756954656862745 and parameters: {'max_depth': 2, 'learning_rate': 0.02394506074401785, 'n_estimators': 175, 'min_child_weight': 11, 'gamma': 0.027669342821482965, 'subsample': 0.9122538551746165, 'colsample_bytree': 0.798302531786037}. Best is trial 39 with value: 0.8803860294117648.
# [I 2026-01-02 01:11:00,419] Trial 42 finished with value: 0.8694454656862746 and parameters: {'max_depth': 4, 'learning_rate': 0.03220085386117583, 'n_estimators': 189, 'min_child_weight': 7, 'gamma': 0.0033475845247688107, 'subsample': 0.7528050192828017, 'colsample_bytree': 0.7617157016649294}. Best is trial 39 with value: 0.8803860294117648.
# [I 2026-01-02 01:11:00,532] Trial 43 finished with value: 0.8764767156862746 and parameters: {'max_depth': 6, 'learning_rate': 0.019201565098598522, 'n_estimators': 158, 'min_child_weight': 6, 'gamma': 0.32733459850231506, 'subsample': 0.9509404735449294, 'colsample_bytree': 0.8415640385023739}. Best is trial 39 with value: 0.8803860294117648.
# [I 2026-01-02 01:11:00,606] Trial 44 finished with value: 0.8733547794117648 and parameters: {'max_depth': 2, 'learning_rate': 0.022802334450668576, 'n_estimators': 132, 'min_child_weight': 3, 'gamma': 0.08150054985354888, 'subsample': 0.3297277687227808, 'colsample_bytree': 0.8780406382046233}. Best is trial 39 with value: 0.8803860294117648.
# [I 2026-01-02 01:11:00,687] Trial 45 finished with value: 0.8702205882352942 and parameters: {'max_depth': 4, 'learning_rate': 0.07367410978857167, 'n_estimators': 170, 'min_child_weight': 9, 'gamma': 0.016375248957729356, 'subsample': 0.620759877006647, 'colsample_bytree': 0.7998906522248876}. Best is trial 39 with value: 0.8803860294117648.
# [I 2026-01-02 01:11:00,783] Trial 46 finished with value: 0.8710018382352942 and parameters: {'max_depth': 8, 'learning_rate': 0.012881274429958144, 'n_estimators': 144, 'min_child_weight': 8, 'gamma': 0.0005473458128817758, 'subsample': 0.7176974292753493, 'colsample_bytree': 0.6996382262513136}. Best is trial 39 with value: 0.8803860294117648.
# [I 2026-01-02 01:11:00,854] Trial 47 finished with value: 0.8639583333333334 and parameters: {'max_depth': 6, 'learning_rate': 0.015686999702093595, 'n_estimators': 114, 'min_child_weight': 11, 'gamma': 0.3992849960078382, 'subsample': 0.3936890373730875, 'colsample_bytree': 0.7187389093974191}. Best is trial 39 with value: 0.8803860294117648.
# [I 2026-01-02 01:11:00,948] Trial 48 finished with value: 0.8694424019607844 and parameters: {'max_depth': 3, 'learning_rate': 0.037305735551870264, 'n_estimators': 181, 'min_child_weight': 2, 'gamma': 0.02904526171761312, 'subsample': 0.7673921909958781, 'colsample_bytree': 0.7564001700451431}. Best is trial 39 with value: 0.8803860294117648.
# [I 2026-01-02 01:11:01,051] Trial 49 finished with value: 0.8764767156862746 and parameters: {'max_depth': 27, 'learning_rate': 0.01011065222436963, 'n_estimators': 153, 'min_child_weight': 3, 'gamma': 0.0026335188085898713, 'subsample': 0.5480796369617211, 'colsample_bytree': 0.9185031177576741}. Best is trial 39 with value: 0.8803860294117648.

# %%
optuna_results['RandomForestClassifier'].best_params
# Out:
# {'n_estimators': 63,
#  'max_depth': 26,
#  'max_features': 'log2',
#  'max_leaf_nodes': 19,
#  'min_samples_split': 4,
#  'min_samples_leaf': 1}

# %%
optuna_results['RandomForestClassifier'].best_value
# Out:
# 0.8811672794117648

# %%
import joblib

RF_best_params = optuna_results['RandomForestClassifier'].best_params
RF_model = RandomForestClassifier(**RF_best_params, random_state=42)
RF_model.fit(X_train, y_train)

XGB_best_params = optuna_results['XGBClassifier'].best_params
XGB_model = XGBClassifier(**XGB_best_params, random_state=42)
XGB_model.fit(X_train, y_train)


joblib.dump(RF_model, '../models/RandomForestClassifier.pkl')
joblib.dump(XGB_model, '../models/XGBClassifier.pkl')
# Out:
# ['../models/XGBClassifier.pkl']
